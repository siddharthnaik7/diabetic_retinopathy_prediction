# %%
#install depenencies
# !pip install kaggle

# %%
#upload the credentials of the kaggle account
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6f6ab1a5-ed3d-4864-8d5d-3627ec1d5efa" name="files[]" multiple disabled />
#      <output id="result-6f6ab1a5-ed3d-4864-8d5d-3627ec1d5efa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"siddharthnaik7","key":"28e0f6c07a924550d841c251e1730ac7"}'}

# %%
#before importing the dataset we want to use this code
# The Kaggle API client expects this file to be in ~/.kaggle,
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
#import the dataset we want to use for our project
# !kaggle competitions download -c aptos2019-blindness-detection

# %%
#lets see the imported files from kaggle competetion
# !ls
# Out:
# kaggle.json  sample_submission.csv  test_images.zip  train_images.zip
# sample_data  test.csv		    train.csv

# %% [markdown]
# # **Unzip Data**

# %%
# !unzip train_images.zip -d ./Train_Images

# %%
# !unzip test_images.zip -d ./Test_Images

# %% [markdown]
# # **Delete Zip Files**

# %%
# !rm -rf test_images.zip

# %%
# !rm -rf train_images.zip

# %% [markdown]
# # **Load Training and Test Information in Dataframes**

# %%
import pandas as pd

df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#         id_code
# 0  0005cfc8afb6
# 1  003f0afdcd15
# 2  006efc72b638
# 3  00836aaacf06
# 4  009245722fa4

# %% [markdown]
# # **Base Line**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Class_Frequency_Count = df_train['diagnosis'].value_counts()
print(str(Class_Frequency_Count) + "\n")
sns.set(style="darkgrid")
sns.barplot(Class_Frequency_Count.index,Class_Frequency_Count.values,alpha=0.9)
plt.title("Frequency Distribution of Classes")
plt.ylabel("Number of Occurances", fontsize=12)
#plt.xticks(rotation=90)
plt.xlabel("Classes", fontsize=12)
plt.show()
# Out:
# 0    1805
# 2     999
# 1     370
# 4     295
# 3     193
# Name: diagnosis, dtype: int64

# %% [markdown]
# # **Directory Structure Creation**

# %%
# !rm -rf Training_Dir
# !rm -rf Validation_Dir

# %%
df_train = df_train.sample(frac=1).reset_index(drop=True)

# %%
import os

train_keyword = 'Training_Dir'
validation_keyword = 'Validation_Dir'
keywords = [train_keyword,validation_keyword]
dir_list = df_train['diagnosis'].tolist()

for keyword in keywords:
  if(not os.path.exists(keyword)):
    os.mkdir(keyword)
  for class_dir in dir_list:
    if(not os.path.exists(keyword+'/'+str(class_dir))):
      os.mkdir(keyword+'/'+str(class_dir))

# %%
import numpy as np
X = np.array(df_train.ix[:, df_train.columns == 'id_code'])
y = np.array(df_train.ix[:, df_train.columns == 'diagnosis'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
la =[]
count = 0
for x in X:
  if x in la:
    print('same')
  else:
    la.append(count)
    count=count+1

# %%
X_update = np.array(la)
X_update =X_update.reshape(-1, 1)

# %%
re = dict(zip(la,df_train['id_code'].tolist()))

# %%
from sklearn.model_selection import train_test_split #  train,test = train_test_split(dataset,test_size=0.20,stratify=True)
train_images_temp, val_images, train_labels_temp, val_labels = train_test_split(X_update, y, test_size=0.2,stratify=y)

# %%
#NU
split = int(0.7 * len(df_train)) # Change V2 0.8 to 0.7

train_dataframe = df_train.iloc[:split]
val_dataframe = df_train.iloc[split:]

#train_images = train_dataframe['id_code']
#train_labels = train_dataframe['diagnosis']
val_images = val_dataframe['id_code'].tolist()
val_labels = val_dataframe['diagnosis'].tolist()

# %%
from imblearn.over_sampling import SMOTE
print("Before OverSampling, counts of label '0': {}".format(sum(train_labels_temp==0)))
print("Before OverSampling, counts of label '1': {} \n".format(sum(train_labels_temp==1)))
print("Before OverSampling, counts of label '2': {}".format(sum(train_labels_temp==2)))
print("Before OverSampling, counts of label '3': {} \n".format(sum(train_labels_temp==3)))
print("Before OverSampling, counts of label '4': {}".format(sum(train_labels_temp==4)))

sm = SMOTE('minority')
train_images, train_labels = sm.fit_sample(train_images_temp, train_labels_temp.ravel())

print('After OverSampling, the shape of train_X: {}'.format(train_images.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(train_labels.shape))

print("Before OverSampling, counts of label '0': {}".format(sum(train_labels==0)))
print("Before OverSampling, counts of label '1': {} \n".format(sum(train_labels==1)))
print("Before OverSampling, counts of label '2': {}".format(sum(train_labels==2)))
print("Before OverSampling, counts of label '3': {} \n".format(sum(train_labels==3)))
print("Before OverSampling, counts of label '4': {}".format(sum(train_labels==4)))
# Out:
# Before OverSampling, counts of label '0': [1444]
# Before OverSampling, counts of label '1': [296]
#
# Before OverSampling, counts of label '2': [799]
# Before OverSampling, counts of label '3': [154]
#
# Before OverSampling, counts of label '4': [236]
# After OverSampling, the shape of train_X: (4219, 1)
# After OverSampling, the shape of train_y: (4219,)
#
# Before OverSampling, counts of label '0': 1444
# Before OverSampling, counts of label '1': 296
#
# Before OverSampling, counts of label '2': 799
# Before OverSampling, counts of label '3': 1444
#
# Before OverSampling, counts of label '4': 236

# %%
train_temp=[]
for ds in train_images:
  train_temp.append(re[ds[0]])
train_images = train_temp
train_labels = train_labels.tolist()

val_temp=[]
for ds in val_images:
  val_temp.append(re[ds[0]])
val_images = val_temp
val_labels = val_labels.tolist()
cx = []
for l in val_labels:
  cx.append(l[0])
val_labels = cx

# %%
list_of_tuples = list(zip(train_images,train_labels))
train_dataframe = pd.DataFrame(list_of_tuples,columns = ['id_code', 'diagnosis'])
train_dataframe = train_dataframe.sample(frac=1).reset_index(drop=True)
train_images = train_dataframe['id_code'].tolist()
train_labels = train_dataframe['diagnosis'].tolist()

# %%
list_of_tuples = list(zip(val_images,val_labels))
val_dataframe = pd.DataFrame(list_of_tuples,columns = ['id_code', 'diagnosis'])
val_dataframe = val_dataframe.sample(frac=1).reset_index(drop=True)
val_images = val_dataframe['id_code'].tolist()
val_labels = val_dataframe['diagnosis'].tolist()

# %%
Class_Frequency_Count = train_dataframe['diagnosis'].value_counts()
print(str(Class_Frequency_Count) + "\n")
sns.set(style="darkgrid")
sns.barplot(Class_Frequency_Count.index,Class_Frequency_Count.values,alpha=0.9)
plt.title("Frequency Distribution of Classes")
plt.ylabel("Number of Occurances", fontsize=12)
#plt.xticks(rotation=90)
plt.xlabel("Classes", fontsize=12)
plt.show()
# Out:
# 3    1444
# 0    1444
# 2     799
# 1     296
# 4     236
# Name: diagnosis, dtype: int64

# %%
Class_Frequency_Count = val_dataframe['diagnosis'].value_counts()
print(str(Class_Frequency_Count) + "\n")
sns.set(style="darkgrid")
sns.barplot(Class_Frequency_Count.index,Class_Frequency_Count.values,alpha=0.9)
plt.title("Frequency Distribution of Classes")
plt.ylabel("Number of Occurances", fontsize=12)
#plt.xticks(rotation=90)
plt.xlabel("Classes", fontsize=12)
plt.show()
# Out:
# 0    361
# 2    200
# 1     74
# 4     59
# 3     39
# Name: diagnosis, dtype: int64

# %%
import shutil as cf
for keyword in keywords:
  image_list = []
  class_list = []
  if(not os.path.exists(keyword)):
    os.mkdir(keyword)
  if keyword == train_keyword:
    image_list = train_images
    class_list = train_labels
  elif keyword == validation_keyword: 
    image_list = val_images
    class_list = val_labels
  for image_info in image_list:
    cl = class_list[image_list.index(image_info)]
    cf.copy('Train_Images/'+str(image_info)+'.png', keyword+'/'+str(cl))

# %%
# !rm -rf Train_Images

# %% [markdown]
# # **Image Data Generator**

# %%
import tensorflow as tf
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Activation
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
print(tf.__version__)

train_dir = 'Training_Dir'
validation_dir = 'Validation_Dir'

train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=10,
      width_shift_range=0.3,
      height_shift_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


validation_datagen = ImageDataGenerator(rescale=1./255)
 
# Change the batchsize according to your system RAM
train_batchsize = 120
val_batchsize = 40
 
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(299, 299),
        batch_size=train_batchsize,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(299, 299),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=False)
# Out:
# 1.14.0
# Found 3127 images belonging to 5 classes.
# Found 733 images belonging to 5 classes.

# %% [markdown]
# # **Fine Tuning Model**

# %%
from keras.applications.inception_resnet_v2 import InceptionResNetV2

# %%
# Finetuning on 5-class dataset
base_model = InceptionResNetV2(include_top=False, pooling='avg', weights='imagenet', input_shape=(299, 299, 3))
outputs = Dense(5, activation='softmax')(base_model.output)
model = keras.Model(base_model.inputs, outputs)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1016 (Conv2D)            (None, 149, 149, 32) 864         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1016 (Batch (None, 149, 149, 32) 96          conv2d_1016[0][0]
# __________________________________________________________________________________________________
# activation_1016 (Activation)    (None, 149, 149, 32) 0           batch_normalization_1016[0][0]
# __________________________________________________________________________________________________
# conv2d_1017 (Conv2D)            (None, 147, 147, 32) 9216        activation_1016[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1017 (Batch (None, 147, 147, 32) 96          conv2d_1017[0][0]
# __________________________________________________________________________________________________
# activation_1017 (Activation)    (None, 147, 147, 32) 0           batch_normalization_1017[0][0]
# __________________________________________________________________________________________________
# conv2d_1018 (Conv2D)            (None, 147, 147, 64) 18432       activation_1017[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1018 (Batch (None, 147, 147, 64) 192         conv2d_1018[0][0]
# __________________________________________________________________________________________________
# activation_1018 (Activation)    (None, 147, 147, 64) 0           batch_normalization_1018[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 73, 73, 64)   0           activation_1018[0][0]
# __________________________________________________________________________________________________
# conv2d_1019 (Conv2D)            (None, 73, 73, 80)   5120        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1019 (Batch (None, 73, 73, 80)   240         conv2d_1019[0][0]
# __________________________________________________________________________________________________
# activation_1019 (Activation)    (None, 73, 73, 80)   0           batch_normalization_1019[0][0]
# __________________________________________________________________________________________________
# conv2d_1020 (Conv2D)            (None, 71, 71, 192)  138240      activation_1019[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1020 (Batch (None, 71, 71, 192)  576         conv2d_1020[0][0]
# __________________________________________________________________________________________________
# activation_1020 (Activation)    (None, 71, 71, 192)  0           batch_normalization_1020[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 35, 35, 192)  0           activation_1020[0][0]
# __________________________________________________________________________________________________
# conv2d_1024 (Conv2D)            (None, 35, 35, 64)   12288       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1024 (Batch (None, 35, 35, 64)   192         conv2d_1024[0][0]
# __________________________________________________________________________________________________
# activation_1024 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1024[0][0]
# __________________________________________________________________________________________________
# conv2d_1022 (Conv2D)            (None, 35, 35, 48)   9216        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_1025 (Conv2D)            (None, 35, 35, 96)   55296       activation_1024[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1022 (Batch (None, 35, 35, 48)   144         conv2d_1022[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1025 (Batch (None, 35, 35, 96)   288         conv2d_1025[0][0]
# __________________________________________________________________________________________________
# activation_1022 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1022[0][0]
# __________________________________________________________________________________________________
# activation_1025 (Activation)    (None, 35, 35, 96)   0           batch_normalization_1025[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 35, 35, 192)  0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_1021 (Conv2D)            (None, 35, 35, 96)   18432       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_1023 (Conv2D)            (None, 35, 35, 64)   76800       activation_1022[0][0]
# __________________________________________________________________________________________________
# conv2d_1026 (Conv2D)            (None, 35, 35, 96)   82944       activation_1025[0][0]
# __________________________________________________________________________________________________
# conv2d_1027 (Conv2D)            (None, 35, 35, 64)   12288       average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1021 (Batch (None, 35, 35, 96)   288         conv2d_1021[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1023 (Batch (None, 35, 35, 64)   192         conv2d_1023[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1026 (Batch (None, 35, 35, 96)   288         conv2d_1026[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1027 (Batch (None, 35, 35, 64)   192         conv2d_1027[0][0]
# __________________________________________________________________________________________________
# activation_1021 (Activation)    (None, 35, 35, 96)   0           batch_normalization_1021[0][0]
# __________________________________________________________________________________________________
# activation_1023 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1023[0][0]
# __________________________________________________________________________________________________
# activation_1026 (Activation)    (None, 35, 35, 96)   0           batch_normalization_1026[0][0]
# __________________________________________________________________________________________________
# activation_1027 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1027[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 35, 35, 320)  0           activation_1021[0][0]
#                                                                  activation_1023[0][0]
#                                                                  activation_1026[0][0]
#                                                                  activation_1027[0][0]
# __________________________________________________________________________________________________
# conv2d_1031 (Conv2D)            (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1031 (Batch (None, 35, 35, 32)   96          conv2d_1031[0][0]
# __________________________________________________________________________________________________
# activation_1031 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1031[0][0]
# __________________________________________________________________________________________________
# conv2d_1029 (Conv2D)            (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1032 (Conv2D)            (None, 35, 35, 48)   13824       activation_1031[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1029 (Batch (None, 35, 35, 32)   96          conv2d_1029[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1032 (Batch (None, 35, 35, 48)   144         conv2d_1032[0][0]
# __________________________________________________________________________________________________
# activation_1029 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1029[0][0]
# __________________________________________________________________________________________________
# activation_1032 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1032[0][0]
# __________________________________________________________________________________________________
# conv2d_1028 (Conv2D)            (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1030 (Conv2D)            (None, 35, 35, 32)   9216        activation_1029[0][0]
# __________________________________________________________________________________________________
# conv2d_1033 (Conv2D)            (None, 35, 35, 64)   27648       activation_1032[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1028 (Batch (None, 35, 35, 32)   96          conv2d_1028[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1030 (Batch (None, 35, 35, 32)   96          conv2d_1030[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1033 (Batch (None, 35, 35, 64)   192         conv2d_1033[0][0]
# __________________________________________________________________________________________________
# activation_1028 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1028[0][0]
# __________________________________________________________________________________________________
# activation_1030 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1030[0][0]
# __________________________________________________________________________________________________
# activation_1033 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1033[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1028[0][0]
#                                                                  activation_1030[0][0]
#                                                                  activation_1033[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 35, 35, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 35, 35, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1037 (Conv2D)            (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1037 (Batch (None, 35, 35, 32)   96          conv2d_1037[0][0]
# __________________________________________________________________________________________________
# activation_1037 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1037[0][0]
# __________________________________________________________________________________________________
# conv2d_1035 (Conv2D)            (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1038 (Conv2D)            (None, 35, 35, 48)   13824       activation_1037[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1035 (Batch (None, 35, 35, 32)   96          conv2d_1035[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1038 (Batch (None, 35, 35, 48)   144         conv2d_1038[0][0]
# __________________________________________________________________________________________________
# activation_1035 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1035[0][0]
# __________________________________________________________________________________________________
# activation_1038 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1038[0][0]
# __________________________________________________________________________________________________
# conv2d_1034 (Conv2D)            (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, 35, 35, 32)   9216        activation_1035[0][0]
# __________________________________________________________________________________________________
# conv2d_1039 (Conv2D)            (None, 35, 35, 64)   27648       activation_1038[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1034 (Batch (None, 35, 35, 32)   96          conv2d_1034[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1036 (Batch (None, 35, 35, 32)   96          conv2d_1036[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1039 (Batch (None, 35, 35, 64)   192         conv2d_1039[0][0]
# __________________________________________________________________________________________________
# activation_1034 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1034[0][0]
# __________________________________________________________________________________________________
# activation_1036 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1036[0][0]
# __________________________________________________________________________________________________
# activation_1039 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1039[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1034[0][0]
#                                                                  activation_1036[0][0]
#                                                                  activation_1039[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 35, 35, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 35, 35, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1043 (Conv2D)            (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1043 (Batch (None, 35, 35, 32)   96          conv2d_1043[0][0]
# __________________________________________________________________________________________________
# activation_1043 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1043[0][0]
# __________________________________________________________________________________________________
# conv2d_1041 (Conv2D)            (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1044 (Conv2D)            (None, 35, 35, 48)   13824       activation_1043[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1041 (Batch (None, 35, 35, 32)   96          conv2d_1041[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1044 (Batch (None, 35, 35, 48)   144         conv2d_1044[0][0]
# __________________________________________________________________________________________________
# activation_1041 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1041[0][0]
# __________________________________________________________________________________________________
# activation_1044 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1044[0][0]
# __________________________________________________________________________________________________
# conv2d_1040 (Conv2D)            (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1042 (Conv2D)            (None, 35, 35, 32)   9216        activation_1041[0][0]
# __________________________________________________________________________________________________
# conv2d_1045 (Conv2D)            (None, 35, 35, 64)   27648       activation_1044[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1040 (Batch (None, 35, 35, 32)   96          conv2d_1040[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1042 (Batch (None, 35, 35, 32)   96          conv2d_1042[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1045 (Batch (None, 35, 35, 64)   192         conv2d_1045[0][0]
# __________________________________________________________________________________________________
# activation_1040 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1040[0][0]
# __________________________________________________________________________________________________
# activation_1042 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1042[0][0]
# __________________________________________________________________________________________________
# activation_1045 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1045[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1040[0][0]
#                                                                  activation_1042[0][0]
#                                                                  activation_1045[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 35, 35, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 35, 35, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1049 (Conv2D)            (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1049 (Batch (None, 35, 35, 32)   96          conv2d_1049[0][0]
# __________________________________________________________________________________________________
# activation_1049 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1049[0][0]
# __________________________________________________________________________________________________
# conv2d_1047 (Conv2D)            (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1050 (Conv2D)            (None, 35, 35, 48)   13824       activation_1049[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1047 (Batch (None, 35, 35, 32)   96          conv2d_1047[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1050 (Batch (None, 35, 35, 48)   144         conv2d_1050[0][0]
# __________________________________________________________________________________________________
# activation_1047 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1047[0][0]
# __________________________________________________________________________________________________
# activation_1050 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1050[0][0]
# __________________________________________________________________________________________________
# conv2d_1046 (Conv2D)            (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1048 (Conv2D)            (None, 35, 35, 32)   9216        activation_1047[0][0]
# __________________________________________________________________________________________________
# conv2d_1051 (Conv2D)            (None, 35, 35, 64)   27648       activation_1050[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1046 (Batch (None, 35, 35, 32)   96          conv2d_1046[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1048 (Batch (None, 35, 35, 32)   96          conv2d_1048[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1051 (Batch (None, 35, 35, 64)   192         conv2d_1051[0][0]
# __________________________________________________________________________________________________
# activation_1046 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1046[0][0]
# __________________________________________________________________________________________________
# activation_1048 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1048[0][0]
# __________________________________________________________________________________________________
# activation_1051 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1051[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1046[0][0]
#                                                                  activation_1048[0][0]
#                                                                  activation_1051[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 35, 35, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 35, 35, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1055 (Batch (None, 35, 35, 32)   96          conv2d_1055[0][0]
# __________________________________________________________________________________________________
# activation_1055 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1055[0][0]
# __________________________________________________________________________________________________
# conv2d_1053 (Conv2D)            (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1056 (Conv2D)            (None, 35, 35, 48)   13824       activation_1055[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1053 (Batch (None, 35, 35, 32)   96          conv2d_1053[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1056 (Batch (None, 35, 35, 48)   144         conv2d_1056[0][0]
# __________________________________________________________________________________________________
# activation_1053 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1053[0][0]
# __________________________________________________________________________________________________
# activation_1056 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1056[0][0]
# __________________________________________________________________________________________________
# conv2d_1052 (Conv2D)            (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, 35, 35, 32)   9216        activation_1053[0][0]
# __________________________________________________________________________________________________
# conv2d_1057 (Conv2D)            (None, 35, 35, 64)   27648       activation_1056[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1052 (Batch (None, 35, 35, 32)   96          conv2d_1052[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1054 (Batch (None, 35, 35, 32)   96          conv2d_1054[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1057 (Batch (None, 35, 35, 64)   192         conv2d_1057[0][0]
# __________________________________________________________________________________________________
# activation_1052 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1052[0][0]
# __________________________________________________________________________________________________
# activation_1054 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1054[0][0]
# __________________________________________________________________________________________________
# activation_1057 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1057[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1052[0][0]
#                                                                  activation_1054[0][0]
#                                                                  activation_1057[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 35, 35, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 35, 35, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_1061 (Conv2D)            (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1061 (Batch (None, 35, 35, 32)   96          conv2d_1061[0][0]
# __________________________________________________________________________________________________
# activation_1061 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1061[0][0]
# __________________________________________________________________________________________________
# conv2d_1059 (Conv2D)            (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1062 (Conv2D)            (None, 35, 35, 48)   13824       activation_1061[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1059 (Batch (None, 35, 35, 32)   96          conv2d_1059[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1062 (Batch (None, 35, 35, 48)   144         conv2d_1062[0][0]
# __________________________________________________________________________________________________
# activation_1059 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1059[0][0]
# __________________________________________________________________________________________________
# activation_1062 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1062[0][0]
# __________________________________________________________________________________________________
# conv2d_1058 (Conv2D)            (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, 35, 35, 32)   9216        activation_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1063 (Conv2D)            (None, 35, 35, 64)   27648       activation_1062[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1058 (Batch (None, 35, 35, 32)   96          conv2d_1058[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1060 (Batch (None, 35, 35, 32)   96          conv2d_1060[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1063 (Batch (None, 35, 35, 64)   192         conv2d_1063[0][0]
# __________________________________________________________________________________________________
# activation_1058 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1058[0][0]
# __________________________________________________________________________________________________
# activation_1060 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1060[0][0]
# __________________________________________________________________________________________________
# activation_1063 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1063[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1058[0][0]
#                                                                  activation_1060[0][0]
#                                                                  activation_1063[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 35, 35, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 35, 35, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1067 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1067 (Batch (None, 35, 35, 32)   96          conv2d_1067[0][0]
# __________________________________________________________________________________________________
# activation_1067 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1067[0][0]
# __________________________________________________________________________________________________
# conv2d_1065 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1068 (Conv2D)            (None, 35, 35, 48)   13824       activation_1067[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1065 (Batch (None, 35, 35, 32)   96          conv2d_1065[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1068 (Batch (None, 35, 35, 48)   144         conv2d_1068[0][0]
# __________________________________________________________________________________________________
# activation_1065 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1065[0][0]
# __________________________________________________________________________________________________
# activation_1068 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1064 (Conv2D)            (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1066 (Conv2D)            (None, 35, 35, 32)   9216        activation_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1069 (Conv2D)            (None, 35, 35, 64)   27648       activation_1068[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1064 (Batch (None, 35, 35, 32)   96          conv2d_1064[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1066 (Batch (None, 35, 35, 32)   96          conv2d_1066[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1069 (Batch (None, 35, 35, 64)   192         conv2d_1069[0][0]
# __________________________________________________________________________________________________
# activation_1064 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1064[0][0]
# __________________________________________________________________________________________________
# activation_1066 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1066[0][0]
# __________________________________________________________________________________________________
# activation_1069 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1069[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1064[0][0]
#                                                                  activation_1066[0][0]
#                                                                  activation_1069[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 35, 35, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 35, 35, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1073 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1073 (Batch (None, 35, 35, 32)   96          conv2d_1073[0][0]
# __________________________________________________________________________________________________
# activation_1073 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1071 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1074 (Conv2D)            (None, 35, 35, 48)   13824       activation_1073[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1071 (Batch (None, 35, 35, 32)   96          conv2d_1071[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1074 (Batch (None, 35, 35, 48)   144         conv2d_1074[0][0]
# __________________________________________________________________________________________________
# activation_1071 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1071[0][0]
# __________________________________________________________________________________________________
# activation_1074 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1074[0][0]
# __________________________________________________________________________________________________
# conv2d_1070 (Conv2D)            (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1072 (Conv2D)            (None, 35, 35, 32)   9216        activation_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1075 (Conv2D)            (None, 35, 35, 64)   27648       activation_1074[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1070 (Batch (None, 35, 35, 32)   96          conv2d_1070[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1072 (Batch (None, 35, 35, 32)   96          conv2d_1072[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1075 (Batch (None, 35, 35, 64)   192         conv2d_1075[0][0]
# __________________________________________________________________________________________________
# activation_1070 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1070[0][0]
# __________________________________________________________________________________________________
# activation_1072 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1072[0][0]
# __________________________________________________________________________________________________
# activation_1075 (Activation)    (None, 35, 35, 64)   0           batch_normalization_1075[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_1070[0][0]
#                                                                  activation_1072[0][0]
#                                                                  activation_1075[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 35, 35, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 35, 35, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1079 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1079 (Batch (None, 35, 35, 32)   96          conv2d_1079[0][0]
# __________________________________________________________________________________________________
# activation_1079 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1077 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1080 (Conv2D)            (None, 35, 35, 48)   13824       activation_1079[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1077 (Batch (None, 35, 35, 32)   96          conv2d_1077[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1080 (Batch (None, 35, 35, 48)   144         conv2d_1080[0][0]
# __________________________________________________________________________________________________
# activation_1077 (Activation)    (None, 35, 35, 32)   0           batch_normalization_1077[0][0]
# __________________________________________________________________________________________________
# activation_1080 (Activation)    (None, 35, 35, 48)   0           batch_normalization_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1076 (Conv2D)            (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_1199 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1199[0][0]
# __________________________________________________________________________________________________
# activation_1202 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1202[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_1199[0][0]
#                                                                  activation_1202[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 8, 8, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 8, 8, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1204 (Conv2D)            (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1204 (Batch (None, 8, 8, 192)    576         conv2d_1204[0][0]
# __________________________________________________________________________________________________
# activation_1204 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1204[0][0]
# __________________________________________________________________________________________________
# conv2d_1205 (Conv2D)            (None, 8, 8, 224)    129024      activation_1204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1205 (Batch (None, 8, 8, 224)    672         conv2d_1205[0][0]
# __________________________________________________________________________________________________
# activation_1205 (Activation)    (None, 8, 8, 224)    0           batch_normalization_1205[0][0]
# __________________________________________________________________________________________________
# conv2d_1203 (Conv2D)            (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1206 (Conv2D)            (None, 8, 8, 256)    172032      activation_1205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1203 (Batch (None, 8, 8, 192)    576         conv2d_1203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1206 (Batch (None, 8, 8, 256)    768         conv2d_1206[0][0]
# __________________________________________________________________________________________________
# activation_1203 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1203[0][0]
# __________________________________________________________________________________________________
# activation_1206 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1206[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_1203[0][0]
#                                                                  activation_1206[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 8, 8, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 8, 8, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1208 (Conv2D)            (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1208 (Batch (None, 8, 8, 192)    576         conv2d_1208[0][0]
# __________________________________________________________________________________________________
# activation_1208 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1208[0][0]
# __________________________________________________________________________________________________
# conv2d_1209 (Conv2D)            (None, 8, 8, 224)    129024      activation_1208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1209 (Batch (None, 8, 8, 224)    672         conv2d_1209[0][0]
# __________________________________________________________________________________________________
# activation_1209 (Activation)    (None, 8, 8, 224)    0           batch_normalization_1209[0][0]
# __________________________________________________________________________________________________
# conv2d_1207 (Conv2D)            (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1210 (Conv2D)            (None, 8, 8, 256)    172032      activation_1209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1207 (Batch (None, 8, 8, 192)    576         conv2d_1207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1210 (Batch (None, 8, 8, 256)    768         conv2d_1210[0][0]
# __________________________________________________________________________________________________
# activation_1207 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1207[0][0]
# __________________________________________________________________________________________________
# activation_1210 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1210[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_1207[0][0]
#                                                                  activation_1210[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 8, 8, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 8, 8, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1212 (Conv2D)            (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1212 (Batch (None, 8, 8, 192)    576         conv2d_1212[0][0]
# __________________________________________________________________________________________________
# activation_1212 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1212[0][0]
# __________________________________________________________________________________________________
# conv2d_1213 (Conv2D)            (None, 8, 8, 224)    129024      activation_1212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1213 (Batch (None, 8, 8, 224)    672         conv2d_1213[0][0]
# __________________________________________________________________________________________________
# activation_1213 (Activation)    (None, 8, 8, 224)    0           batch_normalization_1213[0][0]
# __________________________________________________________________________________________________
# conv2d_1211 (Conv2D)            (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1214 (Conv2D)            (None, 8, 8, 256)    172032      activation_1213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1211 (Batch (None, 8, 8, 192)    576         conv2d_1211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1214 (Batch (None, 8, 8, 256)    768         conv2d_1214[0][0]
# __________________________________________________________________________________________________
# activation_1211 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1211[0][0]
# __________________________________________________________________________________________________
# activation_1214 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1214[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_1211[0][0]
#                                                                  activation_1214[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 8, 8, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 8, 8, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1216 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1216 (Batch (None, 8, 8, 192)    576         conv2d_1216[0][0]
# __________________________________________________________________________________________________
# activation_1216 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1216[0][0]
# __________________________________________________________________________________________________
# conv2d_1217 (Conv2D)            (None, 8, 8, 224)    129024      activation_1216[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1217 (Batch (None, 8, 8, 224)    672         conv2d_1217[0][0]
# __________________________________________________________________________________________________
# activation_1217 (Activation)    (None, 8, 8, 224)    0           batch_normalization_1217[0][0]
# __________________________________________________________________________________________________
# conv2d_1215 (Conv2D)            (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1218 (Conv2D)            (None, 8, 8, 256)    172032      activation_1217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1215 (Batch (None, 8, 8, 192)    576         conv2d_1215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1218 (Batch (None, 8, 8, 256)    768         conv2d_1218[0][0]
# __________________________________________________________________________________________________
# activation_1215 (Activation)    (None, 8, 8, 192)    0           batch_normalization_1215[0][0]
# __________________________________________________________________________________________________
# activation_1218 (Activation)    (None, 8, 8, 256)    0           batch_normalization_1218[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_1215[0][0]
#                                                                  activation_1218[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 5)            7685        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 54,344,421
# Trainable params: 54,283,877
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
for i, layer in enumerate(model.layers):
  if i < 776:
    layer.trainable = False
  else:
    layer.trainable = True

# check the trainable status of the individual layers
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f44d7da9898> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d7da9080> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d7d92518> False
# <keras.layers.core.Activation object at 0x7f44d7d92470> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4ce1198> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d4cc07b8> False
# <keras.layers.core.Activation object at 0x7f44d4c452b0> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825e88a20> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825e57358> False
# <keras.layers.core.Activation object at 0x7f4825e76208> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f4825de5d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825dccd68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825d2a940> False
# <keras.layers.core.Activation object at 0x7f4825d2ada0> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825cc59e8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825cbddd8> False
# <keras.layers.core.Activation object at 0x7f4825c919b0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f4825c07d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825904b00> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825967f98> False
# <keras.layers.core.Activation object at 0x7f48258f1d68> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825b05c50> False
# <keras.layers.convolutional.Conv2D object at 0x7f48258bacc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825b1bb38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825809668> False
# <keras.layers.core.Activation object at 0x7f4825ad8f60> False
# <keras.layers.core.Activation object at 0x7f482581dfd0> False
# <keras.layers.pooling.AveragePooling2D object at 0x7f44e7a4bf98> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825c07be0> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825a22f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f4825780b70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e7a67b00> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825b707b8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825a02cc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f4825772438> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e79d3da0> False
# <keras.layers.core.Activation object at 0x7f4825b70ac8> False
# <keras.layers.core.Activation object at 0x7f4825a39a90> False
# <keras.layers.core.Activation object at 0x7f482577dda0> False
# <keras.layers.core.Activation object at 0x7f44e79d3358> False
# <keras.layers.merge.Concatenate object at 0x7f44e79af048> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e76b8f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e769bcc0> False
# <keras.layers.core.Activation object at 0x7f44e7622f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e78944a8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e75a4908> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e7823358> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e7580fd0> False
# <keras.layers.core.Activation object at 0x7f44e7804240> False
# <keras.layers.core.Activation object at 0x7f44e75408d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e79afda0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e774af60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e74d3cc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e793e1d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e77b0ef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e74a5668> False
# <keras.layers.core.Activation object at 0x7f44e791d198> False
# <keras.layers.core.Activation object at 0x7f44e776dd68> False
# <keras.layers.core.Activation object at 0x7f44e74b9fd0> False
# <keras.layers.merge.Concatenate object at 0x7f44e741db70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e741d630> False
# <keras.layers.core.Lambda object at 0x7f44e7369ef0> False
# <keras.layers.core.Activation object at 0x7f44e73a1978> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e68c0860> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e691ef60> False
# <keras.layers.core.Activation object at 0x7f44e68abb38> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e72ede10> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6854c18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e72cfe48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e67c2470> False
# <keras.layers.core.Activation object at 0x7f44e6a56eb8> False
# <keras.layers.core.Activation object at 0x7f44e67d7dd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e73a1da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e69d6f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6794f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e7322208> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e6a37ef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e672f390> False
# <keras.layers.core.Activation object at 0x7f44e7322fd0> False
# <keras.layers.core.Activation object at 0x7f44e69f5898> False
# <keras.layers.core.Activation object at 0x7f44e6710278> False
# <keras.layers.merge.Concatenate object at 0x7f44e6689f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6689a20> False
# <keras.layers.core.Lambda object at 0x7f44e6627c88> False
# <keras.layers.core.Activation object at 0x7f44e65fdeb8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e63f9b00> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e6365320> False
# <keras.layers.core.Activation object at 0x7f44e63758d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6578cf8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e62c1e48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e6555f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e62f6ba8> False
# <keras.layers.core.Activation object at 0x7f44e64e4cc0> False
# <keras.layers.core.Activation object at 0x7f44e62b5cf8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e65fdcc0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e64abc50> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e61fce48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e658c8d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e63fd5f8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e61dee80> False
# <keras.layers.core.Activation object at 0x7f44e658c780> False
# <keras.layers.core.Activation object at 0x7f44e6412f60> False
# <keras.layers.core.Activation object at 0x7f44e619ec50> False
# <keras.layers.merge.Concatenate object at 0x7f44e60e7f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6116b00> False
# <keras.layers.core.Lambda object at 0x7f44e6054f28> False
# <keras.layers.core.Activation object at 0x7f44e6084278> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5e62e48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e5e18b00> False
# <keras.layers.core.Activation object at 0x7f44e5dd6fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5fccba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5d21f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e5f9e550> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e5d02c88> False
# <keras.layers.core.Activation object at 0x7f44e5fb3eb8> False
# <keras.layers.core.Activation object at 0x7f44e5cbfa58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e6084a20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5f6dfd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5c07ac8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e601ab38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e5e3ffd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44e5c68f60> False
# <keras.layers.core.Activation object at 0x7f44e601a8d0> False
# <keras.layers.core.Activation object at 0x7f44e5eebb00> False
# <keras.layers.core.Activation object at 0x7f44e5c29828> False
# <keras.layers.merge.Concatenate object at 0x7f44e5bbad30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5ba2e48> False
# <keras.layers.core.Lambda object at 0x7f44e5adfac8> False
# <keras.layers.core.Activation object at 0x7f44e5b0ee10> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6afceb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6b5e438> False
# <keras.layers.core.Activation object at 0x7f44d6ae9eb8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6d748d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6a68828> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6cc5198> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6a46ef0> False
# <keras.layers.core.Activation object at 0x7f44d6cc5fd0> False
# <keras.layers.core.Activation object at 0x7f44d6a057f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44e5b0e7b8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6c0edd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d699bbe0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6d5dcf8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6c73e10> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d696a588> False
# <keras.layers.core.Activation object at 0x7f44d6d5d4a8> False
# <keras.layers.core.Activation object at 0x7f44d6c32be0> False
# <keras.layers.core.Activation object at 0x7f44d68b9f98> False
# <keras.layers.merge.Concatenate object at 0x7f44d68e5a90> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d68e5c50> False
# <keras.layers.core.Lambda object at 0x7f44d687f940> False
# <keras.layers.core.Activation object at 0x7f44d682ddd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d65cec18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d65e4e80> False
# <keras.layers.core.Activation object at 0x7f44d6574a58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d67b0d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d651cb38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6792d68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d648f2e8> False
# <keras.layers.core.Activation object at 0x7f44d671edd8> False
# <keras.layers.core.Activation object at 0x7f44d64a2898> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6864860> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d669fe80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6468ef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d67e4080> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d667dfd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6387dd8> False
# <keras.layers.core.Activation object at 0x7f44d67e4ef0> False
# <keras.layers.core.Activation object at 0x7f44d663ba20> False
# <keras.layers.core.Activation object at 0x7f44d63d99b0> False
# <keras.layers.merge.Concatenate object at 0x7f44d6351d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6351f28> False
# <keras.layers.core.Lambda object at 0x7f44d62f1ba8> False
# <keras.layers.core.Activation object at 0x7f44d62c2f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d603ea20> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d6010358> False
# <keras.layers.core.Activation object at 0x7f44d602e208> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d61bf908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d5f8bd68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d621cfd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d5f3fac8> False
# <keras.layers.core.Activation object at 0x7f44d61a8be0> False
# <keras.layers.core.Activation object at 0x7f44d5efdf98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d62c2f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d6172b70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d5e41d68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d62544e0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d60c4518> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d5ea4da0> False
# <keras.layers.core.Activation object at 0x7f44d6254908> False
# <keras.layers.core.Activation object at 0x7f44d6094cc0> False
# <keras.layers.core.Activation object at 0x7f44d5e62b70> False
# <keras.layers.merge.Concatenate object at 0x7f44d5dadfd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d5ddff28> False
# <keras.layers.core.Lambda object at 0x7f44d4a55e48> False
# <keras.layers.core.Activation object at 0x7f44d4a86ba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d47b7f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d481df28> False
# <keras.layers.core.Activation object at 0x7f44d47d9f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4a30ba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4723e80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d49a0470> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d4708f60> False
# <keras.layers.core.Activation object at 0x7f44d49afdd8> False
# <keras.layers.core.Activation object at 0x7f44d46c1b70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4a86b38> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4973eb8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d460f940> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d4a1db38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d48eb160> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d466af98> False
# <keras.layers.core.Activation object at 0x7f44d4a1d7f0> False
# <keras.layers.core.Activation object at 0x7f44d48ebda0> False
# <keras.layers.core.Activation object at 0x7f44d462a908> False
# <keras.layers.merge.Concatenate object at 0x7f44d44f4710> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d453dc50> False
# <keras.layers.core.Lambda object at 0x7f44d4554320> False
# <keras.layers.core.Activation object at 0x7f44d44e09e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4242f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d42a6f28> False
# <keras.layers.core.Activation object at 0x7f44d4230dd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4441cc0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d41ac748> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d4452ba8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d418ce48> False
# <keras.layers.core.Activation object at 0x7f44d4410cf8> False
# <keras.layers.core.Activation object at 0x7f44d414b828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d450f7f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d435dda0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d40c4be0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d44a2d68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d433dd30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d40b24a8> False
# <keras.layers.core.Activation object at 0x7f44d44a2048> False
# <keras.layers.core.Activation object at 0x7f44d42f9b00> False
# <keras.layers.core.Activation object at 0x7f44d4047e10> False
# <keras.layers.merge.Concatenate object at 0x7f44d4003f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d4029b38> False
# <keras.layers.core.Lambda object at 0x7f44d3ef8cf8> False
# <keras.layers.core.Activation object at 0x7f44d3f7f828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3d19c88> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3cea630> False
# <keras.layers.core.Activation object at 0x7f44d3c3d978> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3e7ef60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3c67b70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3eddc88> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3bd8400> False
# <keras.layers.core.Activation object at 0x7f44d3e69f60> False
# <keras.layers.core.Activation object at 0x7f44d3bb92e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3f7f2b0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3de78d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3bb2f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3f12b00> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3dc9f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3b65be0> False
# <keras.layers.core.Activation object at 0x7f44d3f2ef98> False
# <keras.layers.core.Activation object at 0x7f44d3d86898> False
# <keras.layers.core.Activation object at 0x7f44d3b1ed30> False
# <keras.layers.merge.Concatenate object at 0x7f44d3a67f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3a9ac50> False
# <keras.layers.core.Lambda object at 0x7f44d39d9f28> False
# <keras.layers.core.Activation object at 0x7f44d3a08358> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3903828> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3964ef0> False
# <keras.layers.core.Activation object at 0x7f44d38f2b00> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3898be0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d380c438> False
# <keras.layers.core.Activation object at 0x7f44d3818da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3a08c88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d37e5f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d399ce48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3770358> False
# <keras.layers.core.Activation object at 0x7f44d399cb38> False
# <keras.layers.core.Activation object at 0x7f44d3755240> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f44d36cce80> False
# <keras.layers.merge.Concatenate object at 0x7f44d36ccc88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d35c9a90> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d356ffd0> False
# <keras.layers.core.Activation object at 0x7f44d359e780> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d34e7f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d34cdeb8> False
# <keras.layers.core.Activation object at 0x7f44d348ac88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d367cb38> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d33d4f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d363ac88> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d33b6c88> False
# <keras.layers.core.Activation object at 0x7f44d362eba8> False
# <keras.layers.core.Activation object at 0x7f44d33f1a58> False
# <keras.layers.merge.Concatenate object at 0x7f44d32b7ac8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d336af98> False
# <keras.layers.core.Lambda object at 0x7f44d32a8cf8> False
# <keras.layers.core.Activation object at 0x7f44d32d9240> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3204a58> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3177278> False
# <keras.layers.core.Activation object at 0x7f44d3186828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3151da0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d3106b00> False
# <keras.layers.core.Activation object at 0x7f44d30c2fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d32d9828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d3005da0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d326eef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d306ddd8> False
# <keras.layers.core.Activation object at 0x7f44d326e6a0> False
# <keras.layers.core.Activation object at 0x7f44d3028ba8> False
# <keras.layers.merge.Concatenate object at 0x7f44d2f72e80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2fa6f60> False
# <keras.layers.core.Lambda object at 0x7f44d2edde80> False
# <keras.layers.core.Activation object at 0x7f44d2f0ebe0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2e3cba8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2e2d470> False
# <keras.layers.core.Activation object at 0x7f44d2dbedd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2d79eb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2cf4160> False
# <keras.layers.core.Activation object at 0x7f44d2cf4da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2f0eb70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2c3ff98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2eaab38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2ca5f28> False
# <keras.layers.core.Activation object at 0x7f44d2eaa7f0> False
# <keras.layers.core.Activation object at 0x7f44d2c60f60> False
# <keras.layers.merge.Concatenate object at 0x7f44d2badfd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2be0ba8> False
# <keras.layers.core.Lambda object at 0x7f44d2b16e10> False
# <keras.layers.core.Activation object at 0x7f44d2b46c50> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2a47710> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2aa6dd8> False
# <keras.layers.core.Activation object at 0x7f44d2a33a90> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d29dab70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d294f2e8> False
# <keras.layers.core.Activation object at 0x7f44d295e978> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2b46cf8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2918f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2adcc50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d28932b0> False
# <keras.layers.core.Activation object at 0x7f44d2adc9e8> False
# <keras.layers.core.Activation object at 0x7f44d28b12b0> False
# <keras.layers.merge.Concatenate object at 0x7f44d2828d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d280eac8> False
# <keras.layers.core.Lambda object at 0x7f44d27aedd8> False
# <keras.layers.core.Activation object at 0x7f44d277af60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2679fd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d26dcf98> False
# <keras.layers.core.Activation object at 0x7f44d2665ef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d25e2860> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d25c1f60> False
# <keras.layers.core.Activation object at 0x7f44d2580908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d277aa90> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2513cc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d27106d8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d247ac18> False
# <keras.layers.core.Activation object at 0x7f44d2710da0> False
# <keras.layers.core.Activation object at 0x7f44d24e57f0> False
# <keras.layers.merge.Concatenate object at 0x7f44d245fc18> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d245f6d8> False
# <keras.layers.core.Lambda object at 0x7f44d239afd0> False
# <keras.layers.core.Activation object at 0x7f44d23e1ac8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d22fcb70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d230ea58> False
# <keras.layers.core.Activation object at 0x7f44d22caf98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2217f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d21f7cc0> False
# <keras.layers.core.Activation object at 0x7f44d21b4cc0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d23e1ef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d20faf98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d2360320> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d215df60> False
# <keras.layers.core.Activation object at 0x7f44d23606a0> False
# <keras.layers.core.Activation object at 0x7f44d2117b38> False
# <keras.layers.merge.Concatenate object at 0x7f44d2062978> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2093fd0> False
# <keras.layers.core.Lambda object at 0x7f44d1fd1cf8> False
# <keras.layers.core.Activation object at 0x7f44d2001a58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1fa3a58> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1f1d278> False
# <keras.layers.core.Activation object at 0x7f44d1f2e908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1e74e80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1eabbe0> False
# <keras.layers.core.Activation object at 0x7f44d1e62a58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d2001780> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1ddecf8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1f99ef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1d95a58> False
# <keras.layers.core.Activation object at 0x7f44d1f996a0> False
# <keras.layers.core.Activation object at 0x7f44d1d50f60> False
# <keras.layers.merge.Concatenate object at 0x7f44d1c90da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1cc2c88> False
# <keras.layers.core.Lambda object at 0x7f44d1c01ef0> False
# <keras.layers.core.Activation object at 0x7f44d1c36d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1b7bc50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1b8fe80> False
# <keras.layers.core.Activation object at 0x7f44d1b1ab70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1ac8c50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1a344e0> False
# <keras.layers.core.Activation object at 0x7f44d1a02cf8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1c36dd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1a2da58> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1bc4d30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d199f240> False
# <keras.layers.core.Activation object at 0x7f44d1bc4ac8> False
# <keras.layers.core.Activation object at 0x7f44d19348d0> False
# <keras.layers.merge.Concatenate object at 0x7f44d18f8f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d18f8e48> False
# <keras.layers.core.Lambda object at 0x7f44d1861cc0> False
# <keras.layers.core.Activation object at 0x7f44d18e7fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d17e6f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d17c7c18> False
# <keras.layers.core.Activation object at 0x7f44d1749fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d16cc940> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d172cf98> False
# <keras.layers.core.Activation object at 0x7f44d16eb7f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d18e71d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d15fec50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d17fa860> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1612fd0> False
# <keras.layers.core.Activation object at 0x7f44d17fae80> False
# <keras.layers.core.Activation object at 0x7f44d15cf860> False
# <keras.layers.merge.Concatenate object at 0x7f44d1567c18> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1548cf8> False
# <keras.layers.core.Lambda object at 0x7f44d14869b0> False
# <keras.layers.core.Activation object at 0x7f44d14cbba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1468c50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d13fab38> False
# <keras.layers.core.Activation object at 0x7f44d13b89e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d12fdd68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1361da0> False
# <keras.layers.core.Activation object at 0x7f44d131cda0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d14cbfd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1266ef0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d144f400> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d124afd0> False
# <keras.layers.core.Activation object at 0x7f44d144f780> False
# <keras.layers.core.Activation object at 0x7f44d12049e8> False
# <keras.layers.merge.Concatenate object at 0x7f44d114cb00> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d117ee48> False
# <keras.layers.core.Lambda object at 0x7f44d10b6e10> False
# <keras.layers.core.Activation object at 0x7f44d116c9e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d1098b38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d100d470> False
# <keras.layers.core.Activation object at 0x7f44d1017e48> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0fd0f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0f511d0> False
# <keras.layers.core.Activation object at 0x7f44d0f51f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d116ca90> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0ecbe80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d1084fd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0e7cb38> False
# <keras.layers.core.Activation object at 0x7f44d1084780> False
# <keras.layers.core.Activation object at 0x7f44d0e399b0> False
# <keras.layers.merge.Concatenate object at 0x7f44d0d7ef28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0e30c50> False
# <keras.layers.core.Lambda object at 0x7f44d0d4eb70> False
# <keras.layers.core.Activation object at 0x7f44d0da1c88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0c9c8d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0c7af60> False
# <keras.layers.core.Activation object at 0x7f44d0c07c50> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0bd0be0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0ba15c0> False
# <keras.layers.core.Activation object at 0x7f44d0b36f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0da1d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0b1db38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0d2feb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0a8c320> False
# <keras.layers.core.Activation object at 0x7f44d0d2fba8> False
# <keras.layers.core.Activation object at 0x7f44d0a9b9b0> False
# <keras.layers.merge.Concatenate object at 0x7f44d0a58f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0a04b38> False
# <keras.layers.core.Lambda object at 0x7f44d09d5ac8> False
# <keras.layers.core.Activation object at 0x7f44d094cda0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d08d3da0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d092fcf8> False
# <keras.layers.core.Activation object at 0x7f44d083ae48> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d07b6ac8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0818f60> False
# <keras.layers.core.Activation object at 0x7f44d07d7828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0982828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d071f898> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0965b70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d06fff28> False
# <keras.layers.core.Activation object at 0x7f44d0904390> False
# <keras.layers.core.Activation object at 0x7f44d06bf940> False
# <keras.layers.merge.Concatenate object at 0x7f44d0605710> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0650c50> False
# <keras.layers.core.Lambda object at 0x7f44d05f3a90> False
# <keras.layers.core.Activation object at 0x7f44d06227b8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0553d30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0520160> False
# <keras.layers.core.Activation object at 0x7f44d0520940> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0468e48> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d044ae80> False
# <keras.layers.core.Activation object at 0x7f44d0409e80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d06227f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0353fd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d0536dd8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d03b2cf8> False
# <keras.layers.core.Activation object at 0x7f44d0536048> False
# <keras.layers.core.Activation object at 0x7f44d036fcf8> False
# <keras.layers.merge.Concatenate object at 0x7f44d0239fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d02e8f28> False
# <keras.layers.core.Lambda object at 0x7f44d0223ef0> False
# <keras.layers.core.Activation object at 0x7f44d0254198> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0181c18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d016e550> False
# <keras.layers.core.Activation object at 0x7f44d0103f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d00bf908> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d003e2b0> False
# <keras.layers.core.Activation object at 0x7f44d005c2b0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44d0254940> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cffced30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44d01ebac8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cffa0128> False
# <keras.layers.core.Activation object at 0x7f44d01eb860> False
# <keras.layers.core.Activation object at 0x7f44cffa0a90> False
# <keras.layers.merge.Concatenate object at 0x7f44cff19d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cff19f28> False
# <keras.layers.core.Lambda object at 0x7f44cfe38c50> False
# <keras.layers.core.Activation object at 0x7f44cfe8aef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfd88e80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfde5fd0> False
# <keras.layers.core.Activation object at 0x7f44cfd6fd68> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfcb8cc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfca0c18> False
# <keras.layers.core.Activation object at 0x7f44cfc8c7f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfe8af98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfc07c18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfe19668> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfbf2518> False
# <keras.layers.core.Activation object at 0x7f44cfe19710> False
# <keras.layers.core.Activation object at 0x7f44cfb42f98> False
# <keras.layers.merge.Concatenate object at 0x7f44cfb6ea90> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfb6ec50> False
# <keras.layers.core.Lambda object at 0x7f44cfabfba8> False
# <keras.layers.core.Activation object at 0x7f44cfab3e80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf9b5dd8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfa1ddd8> False
# <keras.layers.core.Activation object at 0x7f44cf9a7f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf918f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf906f60> False
# <keras.layers.core.Activation object at 0x7f44cf8c0b38> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cfaec908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf80d978> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cfa6f198> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf869f98> False
# <keras.layers.core.Activation object at 0x7f44cfa6ff60> False
# <keras.layers.core.Activation object at 0x7f44cf827780> False
# <keras.layers.merge.Concatenate object at 0x7f44cf73cd30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf7a0e48> False
# <keras.layers.core.Lambda object at 0x7f44cf6ddb70> False
# <keras.layers.core.Activation object at 0x7f44cf688f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf638550> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf60c240> False
# <keras.layers.core.Activation object at 0x7f44cf62c240> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf583eb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf539a58> False
# <keras.layers.core.Activation object at 0x7f44cf4f5f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf70df28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf438da0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf6a5eb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf4a1dd8> False
# <keras.layers.core.Activation object at 0x7f44cf6a5518> False
# <keras.layers.core.Activation object at 0x7f44cf45cdd8> False
# <keras.layers.merge.Concatenate object at 0x7f44cf3a4f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf3d8b00> False
# <keras.layers.core.Lambda object at 0x7f44cf310fd0> False
# <keras.layers.core.Activation object at 0x7f44cf341278> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf28bc18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf25a630> False
# <keras.layers.core.Activation object at 0x7f44cf2289e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf1d2ac8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf147240> False
# <keras.layers.core.Activation object at 0x7f44cf1588d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf341a20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf11ff28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf2d9ba8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cf0b02e8> False
# <keras.layers.core.Activation object at 0x7f44cf2d9940> False
# <keras.layers.core.Activation object at 0x7f44cf08e1d0> False
# <keras.layers.merge.Concatenate object at 0x7f44cf005f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cf005a20> False
# <keras.layers.core.Lambda object at 0x7f44cefa4d30> False
# <keras.layers.core.Activation object at 0x7f44cef76eb8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ceeeff28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ceed4ef0> False
# <keras.layers.core.Activation object at 0x7f44cee5ae48> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cee23c50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cedb7fd0> False
# <keras.layers.core.Activation object at 0x7f44ced77860> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cef769e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ced0bc18> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cef06630> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cecdc5f8> False
# <keras.layers.core.Activation object at 0x7f44cef06f98> False
# <keras.layers.core.Activation object at 0x7f44cecf1fd0> False
# <keras.layers.merge.Concatenate object at 0x7f44cec58b70> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cec58630> False
# <keras.layers.core.Lambda object at 0x7f44ceb96f28> False
# <keras.layers.core.Activation object at 0x7f44cebdba20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce8518d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce835f60> False
# <keras.layers.core.Activation object at 0x7f44ce7bfc50> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cebdbe48> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cea04d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce785be0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ceb59278> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cea6ad68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce7565c0> False
# <keras.layers.core.Activation object at 0x7f44ceb595f8> False
# <keras.layers.core.Activation object at 0x7f44ce975e80> False
# <keras.layers.core.Activation object at 0x7f44ce76cf98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ceb21f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce96db00> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce6d0b38> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ceb06eb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce951f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce63f320> False
# <keras.layers.core.Activation object at 0x7f44ceac1ef0> False
# <keras.layers.core.Activation object at 0x7f44ce90da90> False
# <keras.layers.core.Activation object at 0x7f44ce64e9b0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f44ce608f98> False
# <keras.layers.merge.Concatenate object at 0x7f44ce5b42e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce532ba8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce484588> False
# <keras.layers.core.Activation object at 0x7f44ce49af60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce454f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce3ee198> False
# <keras.layers.core.Activation object at 0x7f44ce37e828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce5a1198> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce361d68> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce4fada0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce2b4160> False
# <keras.layers.core.Activation object at 0x7f44ce4fa668> False
# <keras.layers.core.Activation object at 0x7f44ce2b4940> False
# <keras.layers.merge.Concatenate object at 0x7f44ce2b1f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce2b1d68> False
# <keras.layers.core.Lambda object at 0x7f44ce1cec88> False
# <keras.layers.core.Activation object at 0x7f44ce221fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce11dcf8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce0faf28> False
# <keras.layers.core.Activation object at 0x7f44ce086da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce005710> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce063dd8> False
# <keras.layers.core.Activation object at 0x7f44ce01f7f0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ce221f28> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdf36b70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ce1ae898> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cdf09550> False
# <keras.layers.core.Activation object at 0x7f44ce1ae748> False
# <keras.layers.core.Activation object at 0x7f44cded6fd0> False
# <keras.layers.merge.Concatenate object at 0x7f44cde81c88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cde81ac8> False
# <keras.layers.core.Lambda object at 0x7f44cde51be0> False
# <keras.layers.core.Activation object at 0x7f44cddcaef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdd49e10> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cddaee10> False
# <keras.layers.core.Activation object at 0x7f44cdcbef60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdc37fd0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cdc9cf98> False
# <keras.layers.core.Activation object at 0x7f44cdc54940> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cde03940> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdba0e80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cdd831d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cdb7ffd0> False
# <keras.layers.core.Activation object at 0x7f44cdd83f98> False
# <keras.layers.core.Activation object at 0x7f44cdb3c7b8> False
# <keras.layers.merge.Concatenate object at 0x7f44cda84828> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdab6ef0> False
# <keras.layers.core.Lambda object at 0x7f44cda71ba8> False
# <keras.layers.core.Activation object at 0x7f44cda19f60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd9cca90> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd99f278> False
# <keras.layers.core.Activation object at 0x7f44cd93b278> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd918d30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd8cea90> False
# <keras.layers.core.Activation object at 0x7f44cd88df98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cdaa3ef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd7d1dd8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd9b5748> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd7b6e10> False
# <keras.layers.core.Activation object at 0x7f44cd9b5550> False
# <keras.layers.core.Activation object at 0x7f44cd7f1e10> False
# <keras.layers.merge.Concatenate object at 0x7f44cd6baf60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd76bb38> False
# <keras.layers.core.Lambda object at 0x7f44cd6a1fd0> False
# <keras.layers.core.Activation object at 0x7f44cd6d7be0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd61cc50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd584be0> False
# <keras.layers.core.Activation object at 0x7f44cd53ca20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd568b00> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd4db278> False
# <keras.layers.core.Activation object at 0x7f44cd4ea908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd6d7c88> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd4b2f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd66bbe0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd421240> False
# <keras.layers.core.Activation object at 0x7f44cd66b978> False
# <keras.layers.core.Activation object at 0x7f44cd3c3240> False
# <keras.layers.merge.Concatenate object at 0x7f44cd39ba58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd39bef0> False
# <keras.layers.core.Lambda object at 0x7f44cd2b9d68> False
# <keras.layers.core.Activation object at 0x7f44cd30fef0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd205f60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd268f28> False
# <keras.layers.core.Activation object at 0x7f44cd1f1e80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd13ad30> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd14ee80> False
# <keras.layers.core.Activation object at 0x7f44cd10d898> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd30fa20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cd0a2c50> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd29e668> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cd072630> False
# <keras.layers.core.Activation object at 0x7f44cd29ef60> False
# <keras.layers.core.Activation object at 0x7f44cd005fd0> False
# <keras.layers.merge.Concatenate object at 0x7f44ccfeb668> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccfebba8> False
# <keras.layers.core.Lambda object at 0x7f44ccf26da0> False
# <keras.layers.core.Activation object at 0x7f44ccf6ea58> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cce34f98> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cce9bef0> False
# <keras.layers.core.Activation object at 0x7f44cce57eb8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccda3f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ccd88c50> False
# <keras.layers.core.Activation object at 0x7f44ccd42a20> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccf6ee80> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccc87f28> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cceed2b0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ccce9ef0> False
# <keras.layers.core.Activation object at 0x7f44cceed630> False
# <keras.layers.core.Activation object at 0x7f44ccca9ac8> False
# <keras.layers.merge.Concatenate object at 0x7f44ccbf1908> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccc20f60> False
# <keras.layers.core.Lambda object at 0x7f44ccb5bc88> False
# <keras.layers.core.Activation object at 0x7f44ccb8df60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccab8b70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ccaa8208> False
# <keras.layers.core.Activation object at 0x7f44cca3c898> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cca01e10> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc9b7b70> False
# <keras.layers.core.Activation object at 0x7f44cc9769e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44ccb8d898> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc8baf60> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44ccb23e80> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc91def0> False
# <keras.layers.core.Activation object at 0x7f44ccb23630> False
# <keras.layers.core.Activation object at 0x7f44cc8dcef0> False
# <keras.layers.merge.Concatenate object at 0x7f44cc820d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc85bc18> False
# <keras.layers.core.Lambda object at 0x7f44cc792e80> False
# <keras.layers.core.Activation object at 0x7f44cc7bfcc0> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc6ba780> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc71be80> False
# <keras.layers.core.Activation object at 0x7f44cc6abb00> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc651be0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc5c7470> False
# <keras.layers.core.Activation object at 0x7f44cc592f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc7bfd68> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc538b70> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc753cc0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc52c1d0> False
# <keras.layers.core.Activation object at 0x7f44cc753a58> False
# <keras.layers.core.Activation object at 0x7f44cc4bb860> False
# <keras.layers.merge.Concatenate object at 0x7f44cc486dd8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc486eb8> False
# <keras.layers.core.Lambda object at 0x7f44cc4131d0> False
# <keras.layers.core.Activation object at 0x7f44cc472198> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc370eb8> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc351400> False
# <keras.layers.core.Activation object at 0x7f44cc2ddf60> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc25c8d0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc23cf60> False
# <keras.layers.core.Activation object at 0x7f44cc1f9860> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc472978> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc140748> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc3867f0> False
# <keras.layers.normalization.BatchNormalization object at 0x7f44cc1a1e48> False
# <keras.layers.core.Activation object at 0x7f44cc386e10> False
# <keras.layers.core.Activation object at 0x7f44cc15e828> False
# <keras.layers.merge.Concatenate object at 0x7f44cc0f2ba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f44cc0d6c88> False
# <keras.layers.core.Lambda object at 0x7f44cc014940> True
# <keras.layers.convolutional.Conv2D object at 0x7f44cc05ab38> True
# <keras.layers.normalization.BatchNormalization object at 0x7f44cbfc0d68> True
# <keras.layers.core.Activation object at 0x7f44cbfda2e8> True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f44cbfa1f28> True
# <keras.layers.core.Dense object at 0x7f44d7da9860> True

# %% [markdown]
# # **Optimization & Model Compile**

# %%
from keras.callbacks import LearningRateScheduler
from math import exp
epoch =20

# %%
momentum = 0.9
sgd = keras.optimizers.SGD(lr=0.001, momentum=momentum, decay=0.0, nesterov=False)

# %%
# Regular Model
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['acc'])

# %% [markdown]
# # **Fit Model**

# %%
label_count=0
total_count=0
class_weights=0
from collections import Counter
labels_count = Counter(lbl for lbl in df_train['diagnosis'])
total_count = sum(labels_count.values())
class_weights = {cls: total_count / count for cls, count in labels_count.items()}

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epoch,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/20
# 27/26 [===============================] - 512s 19s/step - loss: 1.4489 - acc: 0.3726 - val_loss: 1.6182 - val_acc: 0.4925
# Epoch 2/20
# 27/26 [===============================] - 454s 17s/step - loss: 1.2705 - acc: 0.5018 - val_loss: 1.6375 - val_acc: 0.4939
# Epoch 3/20
# 27/26 [===============================] - 455s 17s/step - loss: 1.2195 - acc: 0.5147 - val_loss: 1.6715 - val_acc: 0.4966
# Epoch 4/20
# 27/26 [===============================] - 443s 16s/step - loss: 1.1798 - acc: 0.5395 - val_loss: 1.7313 - val_acc: 0.5048
# Epoch 5/20
# 27/26 [===============================] - 443s 16s/step - loss: 1.1368 - acc: 0.5514 - val_loss: 1.8377 - val_acc: 0.4980
# Epoch 6/20
# 27/26 [===============================] - 456s 17s/step - loss: 1.1240 - acc: 0.5480 - val_loss: 1.6990 - val_acc: 0.5089
# Epoch 7/20
# 27/26 [===============================] - 466s 17s/step - loss: 1.1020 - acc: 0.5724 - val_loss: 1.7227 - val_acc: 0.5102
# Epoch 8/20
# 27/26 [===============================] - 466s 17s/step - loss: 1.1125 - acc: 0.5552 - val_loss: 1.6884 - val_acc: 0.5143
# Epoch 9/20
# 27/26 [===============================] - 473s 18s/step - loss: 1.0847 - acc: 0.5733 - val_loss: 1.7903 - val_acc: 0.5075
# Epoch 10/20
# 27/26 [===============================] - 465s 17s/step - loss: 1.0725 - acc: 0.5675 - val_loss: 1.7348 - val_acc: 0.5130
# Epoch 11/20
# 27/26 [===============================] - 449s 17s/step - loss: 1.0472 - acc: 0.5736 - val_loss: 1.7594 - val_acc: 0.5130
# Epoch 12/20
# 27/26 [===============================] - 445s 16s/step - loss: 1.0746 - acc: 0.5846 - val_loss: 1.7035 - val_acc: 0.5211
# Epoch 13/20
# 27/26 [===============================] - 439s 16s/step - loss: 1.0234 - acc: 0.6033 - val_loss: 1.6856 - val_acc: 0.5211
# Epoch 14/20
# 27/26 [===============================] - 454s 17s/step - loss: 1.0652 - acc: 0.5736 - val_loss: 1.5719 - val_acc: 0.5307
# Epoch 15/20
# 27/26 [===============================] - 444s 16s/step - loss: 1.0380 - acc: 0.5905 - val_loss: 1.6317 - val_acc: 0.5307
# Epoch 16/20
# 27/26 [===============================] - 452s 17s/step - loss: 1.0266 - acc: 0.5879 - val_loss: 1.6472 - val_acc: 0.5280
# Epoch 17/20
# 27/26 [===============================] - 463s 17s/step - loss: 1.0383 - acc: 0.5756 - val_loss: 1.5853 - val_acc: 0.5389
# Epoch 18/20
# 27/26 [===============================] - 449s 17s/step - loss: 1.0165 - acc: 0.5996 - val_loss: 1.6081 - val_acc: 0.5321
# Epoch 19/20
# 27/26 [===============================] - 446s 17s/step - loss: 1.0084 - acc: 0.6024 - val_loss: 1.6779 - val_acc: 0.5293
# Epoch 20/20
# 27/26 [===============================] - 451s 17s/step - loss: 0.9952 - acc: 0.6047 - val_loss: 1.6442 - val_acc: 0.5334

# %% [markdown]
# # **Save Weights For Future Use**

# %%
# Save Weights of the Model for Future Use
model.save_weights('Model_InceptionResnetV2.h5') # V2

# %% [markdown]
# # **Model Accuracy and Loss Plot**

# %%
# Plot

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # **Maximum Accuracy**

# %%
# Max Accuracy

print("Validation Accuracy:", max(history.history['val_acc']))
print("Training Accuracy", max(history.history['acc']))
# Out:
# Validation Accuracy: 0.5388813119224116
# Training Accuracy 0.6034537894793658
